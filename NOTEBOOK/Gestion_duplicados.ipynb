# %%
# Importaciones necesarias
import pandas as pd 
import numpy as np
from word2number import w2n
pd.set_option('display.max_columns', None)


# Imputación de nulos usando métodos avanzados estadísticos
# -----------------------------------------------------------------------
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# Librerías de visualización
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\karin\AppData\Local\Temp\ipykernel_8464\4159511942.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df_duplicados = pd.read_csv("../DATA/df_clean_sin_nulos.csv", index_col=0)

# %% [markdown]
# DUPLICADOS

# %%
a = df_duplicados[df_duplicados.duplicated(keep = False)]

# %%
a.groupby("EMPLOYEENUMBER")["EMPLOYEENUMBER"].count().reset_index(name = "count")
# Out:
# Empty DataFrame
# Columns: [EMPLOYEENUMBER, count]
# Index: []

# %%
df_duplicados.drop_duplicates(keep = "first", inplace = True)

# %%
df_duplicados.duplicated().sum()
# Out:
# 0

# %%
df_duplicados.to_csv("../DATA/df_clean_sin_duplicados.csv")

# %%
df_duplicados["ENVIRONMENTSATISFACTION"].unique()
# Out:
# array([1, 3, 4, 2], dtype=int64)

# %% [markdown]
# # COLUMNA EMPLOYYE NUMBER

# %%
df_duplicados.EMPLOYEENUMBER
# Out:
# 0         162.0
# 1         259.0
# 2         319.0
# 3       Unknown
# 4       Unknown
#          ...
# 1609      967.0
# 1610      972.0
# 1611    Unknown
# 1612      990.0
# 1613    Unknown
# Name: EMPLOYEENUMBER, Length: 1614, dtype: object

# %%
df_duplicados["EMPLOYEENUMBER"].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1609     True
# 1610     True
# 1611     True
# 1612     True
# 1613     True
# Name: EMPLOYEENUMBER, Length: 1614, dtype: bool

# %%
df_employee_duplicados = df_duplicados.iloc[list(df_duplicados["EMPLOYEENUMBER"].duplicated())]
df_employee_duplicados
# Out:
#       Unnamed: 0   AGE ATTRITION BUSINESSTRAVEL DEPARTMENT  DISTANCEFROMHOME  \
# 4              4  46.0        no        Unknown    Unknown                 3
# 8              8  41.0        no        Unknown    Unknown                 2
# 11            11  56.0        no  travel rarely    Unknown                23
# 12            12  38.0        no        Unknown    Unknown                10
# 14            14  55.0        no        Unknown    Unknown                14
# ...          ...   ...       ...            ...        ...               ...
# 1609        1609  36.0       yes  travel rarely    Unknown                 3
# 1610        1610  45.0        no     non-travel    Unknown                 4
# 1611        1611  39.0        no  travel rarely    Unknown                13
# 1612        1612  36.0        no     non-travel    Unknown                 8
# 1613        1613  46.0        no        Unknown    Unknown                 7
#
#       EDUCATION    EDUCATIONFIELD EMPLOYEENUMBER  ENVIRONMENTSATISFACTION  \
# 4             3  technical degree        Unknown                        1
# 8             5           Unknown        Unknown                        2
# 11            3     life sciences        Unknown                        4
# 12            3           medical        Unknown                        2
# 14            4           medical        Unknown                        3
# ...         ...               ...            ...                      ...
# 1609          1     life sciences          967.0                        3
# 1610          2           Unknown          972.0                        3
# 1611          5           Unknown        Unknown                        1
# 1612          4  technical degree          990.0                        1
# 1613          2           medical        Unknown                        4
#
#       GENDER  HOURLYRATE  JOBINVOLVEMENT  JOBLEVEL                 JOBROLE  \
# 4     female        45.0               4         4         sales executive
# 8     female        91.0               3         4                 manager
# 11      male        68.0               3         4  manufacturing director
# 12    female        99.0               1         3       research director
# 14      male        61.0               4         5       research director
# ...      ...         ...             ...       ...                     ...
# 1609    male        51.0               2         3         sales executive
# 1610    male        57.0               3         2   laboratory technician
# 1611    male        41.0               4         3         sales executive
# 1612    male        84.0               3         2         sales executive
# 1613    male        75.0               3         3  manufacturing director
#
#       JOBSATISFACTION MARITALSTATUS  MONTHLYINCOME  MONTHLYRATE  \
# 4                   1      divorced            NaN         7739
# 8                   1       married        16595.0         5626
# 11                  2       married        13402.0        18235
# 12                  3       married        13206.0         3376
# 14                  2        single            NaN        13339
# ...               ...           ...            ...          ...
# 1609                4       married        10325.0         5518
# 1610                2       Unknown         4447.0        23163
# 1611                3        single            NaN         2560
# 1612                4      divorced            NaN        25952
# 1613                3       Unknown        10845.0        24208
#
#       NUMCOMPANIESWORKED  OVERTIME  PERCENTSALARYHIKE  \
# 4                      2       0.0                 12
# 8                      7       0.0                 16
# 11                     4       1.0                 12
# 12                     3       0.0                 12
# 14                     8       0.0                 11
# ...                  ...       ...                ...
# 1609                   1       NaN                 11
# 1610                   1       NaN                 12
# 1611                   0       0.0                 18
# 1612                   4       0.0                 13
# 1613                   6       NaN                 13
#
#       RELATIONSHIPSATISFACTION  STOCKOPTIONLEVEL  TRAININGTIMESLASTYEAR  \
# 4                            4                 1                      5
# 8                            2                 1                      2
# 11                           1                 1                      0
# 12                           1                 1                      3
# 14                           4                 0                      3
# ...                        ...               ...                    ...
# 1609                         1                 1                      6
# 1610                         2                 0                      5
# 1611                         4                 0                      3
# 1612                         4                 2                      3
# 1613                         2                 1                      3
#
#       WORKLIFEBALANCE  YEARSATCOMPANY  YEARSSINCELASTPROMOTION  \
# 4                 3.0              19                        2
# 8                 3.0              18                       11
# 11                3.0              19                       15
# 12                3.0              18                        1
# 14                3.0              24                        2
# ...               ...             ...                      ...
# 1609              3.0              16                        3
# 1610              2.0               9                        0
# 1611              3.0               8                        0
# 1612              3.0               7                        0
# 1613              3.0               8                        0
#
#       YEARSWITHCURRMANAGER  REMOTEWORK  DAILYRATE  PERFORMANCERATING  \
# 4                        8           0     1319.0           3.000000
# 8                        8           0     1276.0           3.000000
# 11                       9           0     1369.0           3.141709
# 12                      11           1      201.0           3.000000
# 14                      15           0      692.0           3.000000
# ...                    ...         ...        ...                ...
# 1609                     7           0      530.0           3.153740
# 1610                     8           1      805.0           3.000000
# 1611                     7           1      903.0           3.000000
# 1612                     7           0     1229.0           3.146160
# 1613                     7           0      566.0           3.000000
#
#       TOTALWORKINGYEARS
# 4             11.714245
# 8             22.000000
# 11            33.000000
# 12            10.849638
# 14            11.229354
# ...                 ...
# 1609          11.104071
# 1610          11.316743
# 1611           9.000000
# 1612          12.000000
# 1613          11.131911
#
# [534 rows x 33 columns]

# %%
df_employee_duplicados["EMPLOYEENUMBER"].value_counts()
# Out:
# EMPLOYEENUMBER
# Unknown    430
# 376.0        1
# 682.0        1
# 663.0        1
# 653.0        1
#           ...
# 433.0        1
# 424.0        1
# 423.0        1
# 1927.0       1
# 990.0        1
# Name: count, Length: 105, dtype: int64

# %%
len(df_employee_duplicados["EMPLOYEENUMBER"].to_list())
# Out:
# 534

# %%
df_employee_967 = df_duplicados[df_duplicados ["EMPLOYEENUMBER"]== "990.0"]
df_employee_967
# Out:
#       Unnamed: 0   AGE ATTRITION BUSINESSTRAVEL DEPARTMENT  DISTANCEFROMHOME  \
# 369          369  36.0        no     non-travel    Unknown                 8
# 1612        1612  36.0        no     non-travel    Unknown                 8
#
#       EDUCATION    EDUCATIONFIELD EMPLOYEENUMBER  ENVIRONMENTSATISFACTION  \
# 369           4  technical degree          990.0                        1
# 1612          4  technical degree          990.0                        1
#
#      GENDER  HOURLYRATE  JOBINVOLVEMENT  JOBLEVEL          JOBROLE  \
# 369    male        84.0               3         2  sales executive
# 1612   male        84.0               3         2  sales executive
#
#       JOBSATISFACTION MARITALSTATUS  MONTHLYINCOME  MONTHLYRATE  \
# 369                 4      divorced            NaN        25952
# 1612                4      divorced            NaN        25952
#
#       NUMCOMPANIESWORKED  OVERTIME  PERCENTSALARYHIKE  \
# 369                    4       0.0                 13
# 1612                   4       0.0                 13
#
#       RELATIONSHIPSATISFACTION  STOCKOPTIONLEVEL  TRAININGTIMESLASTYEAR  \
# 369                          4                 2                      3
# 1612                         4                 2                      3
#
#       WORKLIFEBALANCE  YEARSATCOMPANY  YEARSSINCELASTPROMOTION  \
# 369               3.0               7                        0
# 1612              3.0               7                        0
#
#       YEARSWITHCURRMANAGER  REMOTEWORK  DAILYRATE  PERFORMANCERATING  \
# 369                      7           1     1229.0            3.14616
# 1612                     7           0     1229.0            3.14616
#
#       TOTALWORKINGYEARS
# 369                12.0
# 1612               12.0

# %%
df_duplicados["EMPLOYEENUMBER"].dtypes
# Out:
# dtype('O')
