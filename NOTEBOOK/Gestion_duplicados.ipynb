# %%
# Importaciones necesarias
import pandas as pd 
import numpy as np
from word2number import w2n
pd.set_option('display.max_columns', None)


# Imputación de nulos usando métodos avanzados estadísticos
# -----------------------------------------------------------------------
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# Librerías de visualización
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_duplicados = pd.read_csv("../DATA/df_clean_sin_nulos.csv", index_col=0)

# %% [markdown]
# DUPLICADOS

# %%
a = df_duplicados[df_duplicados.duplicated(keep = False)]

# %%
a.groupby("EMPLOYEENUMBER")["EMPLOYEENUMBER"].count().reset_index(name = "count")
# Out:
#    EMPLOYEENUMBER  count
# 0          1053.0      2
# 1          1140.0      2
# 2          1161.0      2
# 3          1195.0      2
# 4          1778.0      2
# 5          1804.0      2
# 6          1849.0      2
# 7          1898.0      2
# 8          1954.0      2
# 9           307.0      2
# 10          374.0      2
# 11          424.0      2
# 12          440.0      2
# 13          446.0      2
# 14          455.0      2
# 15          476.0      2
# 16          488.0      2
# 17          523.0      2
# 18          526.0      2
# 19          534.0      2
# 20          544.0      2
# 21          595.0      2
# 22          616.0      2
# 23          621.0      2
# 24          663.0      2
# 25          682.0      2
# 26          721.0      2
# 27          733.0      2
# 28          734.0      2
# 29          742.0      2
# 30          762.0      2
# 31          793.0      2
# 32          803.0      2
# 33          809.0      2
# 34          967.0      2
# 35        Unknown     36

# %%
df_duplicados.drop_duplicates(keep = "first", inplace = True)

# %%
df_duplicados.duplicated().sum()
# Out:
# 0

# %%
df_duplicados.to_csv("../DATA/df_clean_sin_duplicados.csv")

# %%
df_duplicados["ENVIRONMENTSATISFACTION"].unique()
# Out:
# array([1, 3, 4, 2], dtype=int64)

# %% [markdown]
# # COLUMNA EMPLOYEE NUMBER

# %%
df_duplicados.EMPLOYEENUMBER
# Out:
# 0         162.0
# 1         259.0
# 2         319.0
# 3       Unknown
# 4       Unknown
#          ...
# 1608      966.0
# 1610      972.0
# 1611    Unknown
# 1612      990.0
# 1613    Unknown
# Name: EMPLOYEENUMBER, Length: 1561, dtype: object

# %%
df_duplicados["EMPLOYEENUMBER"].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1608     True
# 1610     True
# 1611     True
# 1612     True
# 1613     True
# Name: EMPLOYEENUMBER, Length: 1561, dtype: bool

# %%
df_employee_duplicados = df_duplicados.iloc[list(df_duplicados["EMPLOYEENUMBER"].duplicated())]
df_employee_duplicados
# Out:
#        AGE  ATTRITION BUSINESSTRAVEL DEPARTMENT  DISTANCEFROMHOME  EDUCATION  \
# 4     46.0          0        Unknown    Unknown                 3          3
# 8     41.0          0        Unknown    Unknown                 2          5
# 11    56.0          0  travel rarely    Unknown                23          3
# 12    38.0          0        Unknown    Unknown                10          3
# 14    55.0          0        Unknown    Unknown                14          4
# ...    ...        ...            ...        ...               ...        ...
# 1608  32.0          0        Unknown    Unknown                 3          4
# 1610  45.0          0     non-travel    Unknown                 4          2
# 1611  39.0          0  travel rarely    Unknown                13          5
# 1612  36.0          0     non-travel    Unknown                 8          4
# 1613  46.0          0        Unknown    Unknown                 7          2
#
# ...

# %%
df_employee_duplicados["EMPLOYEENUMBER"].value_counts()
# Out:
# EMPLOYEENUMBER
# Unknown    412
# 448.0        1
# 608.0        1
# 586.0        1
# 500.0        1
#           ...
# 501.0        1
# 502.0        1
# 507.0        1
# 517.0        1
# 990.0        1
# Name: count, Length: 70, dtype: int64

# %%
len(df_employee_duplicados["EMPLOYEENUMBER"].to_list())
# Out:
# 481

# %%
df_employee_967 = df_duplicados[df_duplicados ["EMPLOYEENUMBER"]== "990.0"]
df_employee_967
# Out:
#        AGE  ATTRITION BUSINESSTRAVEL DEPARTMENT  DISTANCEFROMHOME  EDUCATION  \
# 369   36.0          0     non-travel    Unknown                 8          4
# 1612  36.0          0     non-travel    Unknown                 8          4
#
#         EDUCATIONFIELD EMPLOYEENUMBER  ENVIRONMENTSATISFACTION GENDER  \
# 369   technical degree          990.0                        1   male
# 1612  technical degree          990.0                        1   male
#
#       HOURLYRATE  JOBINVOLVEMENT  JOBLEVEL          JOBROLE  JOBSATISFACTION  \
# 369         84.0               3         2  sales executive                4
# 1612        84.0               3         2  sales executive                4
#
#      MARITALSTATUS  MONTHLYINCOME  MONTHLYRATE  NUMCOMPANIESWORKED  OVERTIME  \
# 369       divorced            NaN        25952                   4       0.0
# 1612      divorced            NaN        25952                   4       0.0
#
# ...

# %%
df_duplicados["EMPLOYEENUMBER"].dtypes
# Out:
# dtype('O')
