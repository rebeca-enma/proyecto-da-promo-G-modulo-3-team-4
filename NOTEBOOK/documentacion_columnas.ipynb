# %% [markdown]
# # DOCUMENTACIÓN COLUMNAS DATA FRAME
# ## DOCUMENTACIÓN PREVIA A LA LIMPIEZA DE DATOS
#
# -Los nombres de las columnas se encontraban en diferentes formatos (con mayúsculas, minúsculas, combinación de ambas):
#     - Se decide renombrar los nombres en mayúsculas.
# - Al hacer una revisión de las columnas se deciden eliminar 'Date Birth','Employee count', 'Number Children', 'Over 18', 'Role Departament', 'Salary', 'Same As Monthly Income', 'Years In Current Role', 'Stand Hours'.
#
# - Las columnas 'Atrittion', 'Business Travel', 'Departament', 'Education Field', 'Job Role', 'Marital Status', 'Gender', 'Over Time', 'Remote Work' son de tipo STRING.
#
# - El número de datos por columna es de 1614.
#
# A continuación, se desarrolla con detalle cada una de las columnas del data frame y las modificaciones realizadas a las mismas:
#
# ✅ Age: La edad del empleado.
#     - Datos únicos: 54
# Todos los números encontrados son tipo string y se han cambiado a integer.
# Se han encontrado edades 'por escrito', se han cambiado a número.
#
#
# ✅ Attrition: Indica si el empleado ha dejado la empresa ("No" significa que no ha dejado la empresa y "Yes" significa que ha dejado la empresa).
#     - Datos únicos: 2
#     - Valores: 'Yes' o 'No'
#
# ✅ BusinessTravel: Describe la frecuencia de los viajes relacionados con el trabajo del empleado (por ejemplo, "Travel_Rarely" para raramente).
#     - Datos únicos: 4
#     - Valores son de tipo string: nan, 'travel_rarely','travel_frequently'  y 'non-travel'.
#     - GESTIÓN NULOS: Se sustituirá Nan por 'desconocido'.
#
#
# ✅ DailyRate: La tarifa diaria del empleado.
#     - Datos únicos: 849
#     - Valores son de tipo string, se han modificado a integer.
#     - Se reemplaza ',' por '.' y eliminamos el signo del dólar.
#     - GESTIÓN NULOS: Se sustituirá Nan con Iterative - Knn
#
# ✅ Departament: El departamento en el que trabaja el empleado (por ejemplo, "Research & Development", "Sales", etc.).
#     - Datos únicos: 4
#     - Valores son de tipo string: nan, 'Research & Development', 'Sales' y 'Human Resources'.
#     - GESTIÓN NULOS: Se sustituirá Nan por 'desconocido' o BORRAR ¿?
#
#
# 👀⛔
# DistanceFromHome: La distancia desde el hogar del empleado hasta su lugar de trabajo.
#     - Datos únicos: 69
#     - Los valores son de tipo string, se han modificado a integer.
#     - Tienen números NEGATIVOS.
#
#
# ✅ Education: Nivel de educación del empleado.
#     - Datos únicos: 5
#     - Los valores son de tipo string, se han modificado a integer.
#     - Valores: escala numérica del 1 al 5.
#
# ✅ EducationField: El campo de educación del empleado.
#     - Datos únicos: 7
#     - Valores son de tipo string: nan, 'Life Sciences', 'Technical Degree', 'Medical', 'Other', 'Marketing' y'Human Resources'.
#     - GESTIÓN NULOS: Se sustituirá Nan por 'desconocido'.
#
# ✅ EmployeeCount: Un contador que generalmente es 1 y se usa para contar empleados.
#     - Datos únicos: 1
#     - Valores son de tipo string.
#     - Razón para la eliminación: Se ha decidido eliminar esta columna ya que se considera innecesaria y sin utilidad para el análisis de datos de la empresa. La columna no aporta información relevante para los objetivos del análisis y su eliminación no afecta la calidad o integridad de los datos.
#
# 👀⛔ EmployeeNumber: Un número de identificación único para el empleado.
#     - Datos únicos: 1080
#     - Valores son de tipo string, se modifican a integer.
#     - Contiene valores nulos.
#     - Gestión nulos: Generar nuestro propio ID autoincrement
#
# 👀⛔ EnvironmentSatisfaction: Nivel de satisfacción del empleado en relación con su entorno de trabajo.
#     - Datos únicos: 38
#     - Valores son de tipo string, se modifican a integer.
#     - Valores que estan comprendidos entre el 1 y el 4, siendo el 4 el nivel de máxima satisfacción.
#
# - Revisar numeros grandes. Parece que sobra el número final y coincide el número inicio ¿?
#
# ✅ Gender: El género del empleado. Donde 0 corresponde con "hombre" y 1 con "mujer".
#     - Datos únicos: 2
#     - Valores son de tipo string: 0 y 1.
#     - Se reemplazan los valores 0 por male y 1 por female para mejor entendimiento e interpretación de los datos.
#
# ✅ HourlyRate: La tarifa por hora del empleado.
#     - Datos únicos: 72
#     - Valores son de tipo string, se modifican a integer.
#     - Contiene valores numéricos y 'Not Avaible' que se modifica por valor nulo(nan) para mejor interpretración de los datos.
#
#
# ✅ JobInvolvement: Nivel de implicación del empleado en su trabajo.
#     - Datos únicos: 4
#     - Valores son de tipo string, se modifican a integer: escala numérica del 1 al 4.
#
# ✅ JobLevel: Nivel jerárquico del empleado en la empresa.
#     - Datos únicos: 5
#     - Valores son de tipo string, se modifican a integer: escala numérica del 1 al 5.
#
# ✅ JobRole: El rol o puesto de trabajo del empleado.
#     - Datos únicos: 1579
#     - Valores son de tipo string: 'Research Director', 'Sales executive', 'manager', 'research scientist', 'manufacturing director', 'healthcare representative', 'laboratory technician' y 'human resources'.
#     - Se observa una falta de coherencia en los datos de la tabla debido a la presencia de errores de escritura, así como al uso inconsistente de mayúsculas y minúsculas en los valores.
#     - Se realiza conversión de los datos a minúsculas.
#
# ✅ JobSatisfaction: Nivel de satisfacción del empleado con su trabajo.
#     - Datos únicos: 4
#     - Valores son de tipo string, se modifican a integer: escala numérica del 1 al 4.
#
# ✅ MaritalStatus: El estado civil del empleado (por ejemplo, "Single", "Married", etc.).
#     - Datos únicos: 6
#     - Valores son de tipo string: nan, 'married', 'divorced' y 'single'.
#     - Se observa una falta de coherencia en los datos de la tabla debido a la presencia de errores de escritura, así como al uso inconsistente de mayúsculas y minúsculas en los valores.
#     - Se realiza conversión de los datos a minúsculas y corrección de errores ortográficos con uso de patrones Regex.
#     - GESTIÓN NULOS: Se sustituirá Nan por 'desconocido'.
#
#
# ✅ MonthlyIncome: Ingresos mensuales del empleado.
#     - Datos únicos: 669
#     - Valores son de tipo string, se modifican a integer.
#     - Contiene valores nulos(nan).
#
#  👀⛔ MonthlyRate: Tasa mensual del empleado.
#     - Datos únicos: 1427
#     - Valores son de tipo string, se modifican a integer.
#     - Contiene valores nulos(nan).
#
# ✅ NumCompaniesWorked: Número de compañías en las que el empleado ha trabajado.
#     - Datos únicos: 9
#     - Valores son de tipo string, se modifican a integer: escala numérica del 1 al 9.
#
# ✅ Over18: Indica si el empleado es mayor de 18 años.
#     - Datos únicos: 2
#     - Valores son de tipo string.
#     - Razón para la eliminación: existe otra columna en el conjunto de datos, específicamente la columna 'Age', que proporciona información suficiente para inferir si un individuo es mayor o menor de 18 años. Su eliminación contribuye a simplificar el conjunto de datos y a centrar el análisis en los atributos más relevantes para los objetivos del estudio.
#
# ✅ OverTime: Indica si el empleado trabaja horas extras ("Yes" para sí o "No" para no).
#     - Datos únicos: 3
#     - Valores son de tipo string: nan, 'Yes'y 'No'.
#
# ✅ PercentSalaryHike: El porcentaje de aumento salarial del empleado.
#     - Datos únicos: 15
#     - Valores son de tipo string, se modifican a integer.
#
# ✅ PerformanceRating: Calificación de rendimiento del empleado.
#     - Datos únicos: 3
#     - Valores son de tipo string, se modifican a integer: nan, '3' y '4'.
#
# ✅ RelationshipSatisfaction: Nivel de satisfacción en las relaciones interpersonales del empleado.
#     - Datos únicos: 4
#     - Valores son de tipo string, se modifican a integer: escala numérica del 1 al 4.
#
# ✅ StandardHours: Las horas estándar de trabajo.
#     - Datos únicos: 2
#     - Valores son de tipo string, se modifican a integer: nan y '80'.
#     - Razón para la eliminación: la columna ha sido eliminada debido a la alta prevalencia de valores nulos, lo que resulta en un conjunto de datos insuficiente para el análisis. Su eliminación contribuye a simplificar el conjunto de datos y a centrar el análisis en los atributos más relevantes para los objetivos del estudio.
#
# ✅ StockOptionLevel: Nivel de opciones de compra de acciones del empleado.
#     - Datos únicos: 4
#     - Valores son de tipo string, se modifican a integer: escala numérica del 0 al 4.
#
# ✅ TotalWorkingYears: Total de años de experiencia laboral del empleado.
#     - Datos únicos: 41
#     - Valores son de tipo string, se modifican a integer: valores numéricos y nulos(nan).
#     - Gestión de nulos con valores 'vecinos'.
#
# ✅ TrainingTimesLastYear: Número de veces que el empleado recibió capacitación el año pasado.
#     - Datos únicos: 7
#     - Valores son de tipo string, se modifican a integer: escala numérica del 0 al 6.
#
# ✅ WorkLifeBalance: Equilibrio entre trabajo y vida personal del empleado.
#     - Datos únicos: 5
#     - Valores son de tipo string, se modifican a integer: escala numérica del 1 al 4 y valores nulos(nan).
#     - Gestión de nulos con la moda:
#
# ✅ YearsAtCompany: Años que el empleado ha trabajado en la empresa actual.
#     - Datos únicos: 37
#     - Valores son de tipo string y se modifican a integer: valores numéricos.
#
# ✅ YearsInCurrentRole: Años que el empleado ha estado en su puesto actual.
#     - Datos únicos: 11
#     - Valores son de tipo string.
#     - Razón para la eliminación: la columna ha sido eliminada debido a la alta prevalencia de valores nulos, lo que resulta en un conjunto de datos insuficiente para el análisis. Su eliminación contribuye a simplificar el conjunto de datos y a centrar el análisis en los atributos más relevantes para los objetivos del estudio.
#
# ✅ YearsSinceLastPromotion: Años desde la última promoción del empleado.
#     - Datos únicos: 16
#     - Valores son de tipo string, se modifican a integer: valores numéricos.
#
# ✅ YearsWithCurrManager: Años que el empleado ha estado bajo la supervisión del actual gerente.
#     - Datos únicos: 18
#     - Valores son de tipo string, se modifican a integer: valores numéricos.
#
# ✅ SameAsMonthlyIncome: Ingresos mensuales del empleado.
#     - Datos únicos: 669
#     - Valores son de tipo string.
#     - Razón para la eliminación: se ha identificado que existe otra columna llamada Monthly Income que contiene la misma información que la columna eliminada. Al eliminar esta columna redundante, se mejora la eficiencia del análisis al reducir la complejidad del conjunto de datos y centrar la atención en los atributos más importantes para los objetivos del estudio.
#
# ✅ DateBirth: Año de nacimiento del empleado (teniendo en cuenta que los datos fueron recogidos en el 2023)
#     - Datos únicos: 43
#     - Valores son de tipo string.
#     - Razón para la eliminación: ha sido eliminada debido a que existe otra columna en el conjunto de datos, la columna 'Age', que proporciona información similar. La presencia de ambas columnas con datos relacionados con la fecha de nacimiento y la edad resulta redundante y puede complicar el análisis.
#
# ✅ Salary: Salario de los empleados.
#     - Datos únicos: 1
#     - Valores son de tipo string.
#     - Razón para la eliminación: se ha identificado que los datos contenidos en esta columna no son correctos. Todos los valores son iguales en todas las filas. Esta falta de variabilidad hace que la columna 'Salary' no aporte información útil para el análisis y, por lo tanto, se considera innecesaria.
#     - En caso de necesidad, Se creará la columna 'Salary' a partir de 'Monthly Income', multiplicando los valores por 12 para representar los ingresos anuales, mejorando así la precisión y permitiendo un análisis exhaustivo de los datos salariales.
#
# ✅ RoleDepartament: El departamento y el rol del empleado.
#     - Datos únicos: 302
#     - Valores son de tipo string.
#     - Razón para la eliminación: se eliminó debido a la redundancia con las columnas 'Department' y 'Job Role', que contienen información similar. Su presencia generaba datos incorrectos y muchos valores nulos, lo que dificultaba el análisis preciso de los datos.
#
# ✅ NumberChildren: Número de hijos de los empleados.
#     - Datos únicos: 1
#     - Valores son de tipo string: únicamente valores nulos.
#     - Razón para la eliminación: todos sus valores son nulos, lo que impide realizar un análisis efectivo de los datos y no proporciona información útil para el estudio.
#
# ✅ RemoteWork: Si el empleado puede teletrabajar o no.
#     - Datos únicos: 5
#     - Valores son de tipo string, se modifican a integer: 'Yes', 'True', 'False', '1' y '0'.
#     - Se comprueba que los valores 'Yes', 'True' y '1' son el mismo valor y a su vez, los valores 'No' y '0'.
#     - Se decide reemplazar estos valores por datos numéricos '1' y '0'.
