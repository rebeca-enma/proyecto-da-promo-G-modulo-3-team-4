# %%
import pandas as pd 
import numpy as np
# from num2words import num2words
# from word2number import w2n

# %%
df_data = pd.read_csv("../DATA/DATA.csv", index_col= 0)

# %%
lista_age = df_data["Age"].to_list()

# %%
lista_age
# Out:
# ['51',
#  '52',
#  '42',
#  '47',
#  '46',
#  '48',
#  '59',
#  '42',
#  '41',
#  '41',
#  '41',
#  '56',
#  '38',
#  '41',
#  '55',
#  '40',
#  '58',
#  '46',
#  '35',
#  '40',
#  '45',
#  '33',
#  '36',
#  '47',
#  '36',
#  '35',
#  '52',
#  '36',
#  '33',
#  '34',
#  '41',
#  'forty-seven',
#  '53',
#  '35',
#  '34',
#  '46',
#  '43',
#  '36',
#  '60',
#  '40',
#  '32',
#  '41',
#  '53',
#  '36',
#  '46',
#  '38',
#  '51',
#  '43',
#  '37',
#  '32',
#  '38',
#  '46',
#  '35',
#  '43',
#  '56',
#  '36',
#  '38',
#  '49',
#  '39',
#  '40',
#  '36',
#  '37',
#  '35',
#  '33',
#  '50',
#  '48',
#  '44',
#  '44',
#  '40',
#  '34',
#  '35',
#  '50',
#  '49',
#  '38',
#  '33',
#  '47',
#  '38',
#  '37',
#  '30',
#  'fifty-eight',
#  '34',
#  '58',
#  '38',
#  '29',
#  '55',
#  '41',
#  '39',
#  '38',
#  '43',
#  '31',
#  '50',
#  '35',
#  '47',
#  '35',
#  '40',
#  '45',
#  '33',
#  '36',
#  '45',
#  '51',
#  '34',
#  '43',
#  '34',
#  '38',
#  '48',
#  '34',
#  '32',
#  '29',
#  '46',
#  '30',
#  '45',
#  '30',
#  '30',
#  '34',
#  '51',
#  '34',
#  '35',
#  '45',
#  '39',
#  '31',
#  '39',
#  '45',
#  '30',
#  '31',
#  '36',
#  '36',
#  '55',
#  '35',
#  '42',
#  '52',
#  '49',
#  '34',
#  '33',
#  '33',
#  '53',
#  '49',
#  '35',
#  '38',
#  '46',
#  '36',
#  '42',
#  '34',
#  '30',
#  '54',
#  '31',
#  '44',
#  '55',
#  '44',
#  '34',
#  '39',
#  '55',
#  '51',
#  '58',
#  '48',
#  '29',
#  '34',
#  '42',
#  '57',
#  '34',
#  '54',
#  '34',
#  '29',
#  '35',
#  '35',
#  '34',
#  '43',
#  '58',
#  '36',
#  '43',
#  '55',
#  '42',
#  '40',
#  '56',
#  '39',
#  '53',
#  '27',
#  '30',
#  '35',
#  '32',
#  '30',
#  '46',
#  '30',
#  '32',
#  '35',
#  '32',
#  '41',
#  '40',
#  '45',
#  '32',
#  '30',
#  '37',
#  '37',
#  '40',
#  '36',
#  '32',
#  '38',
#  '30',
#  '39',
#  '60',
#  '30',
#  '31',
#  '33',
#  '50',
#  '32',
#  '42',
#  '49',
#  '27',
#  '33',
#  '52',
#  '32',
#  '36',
#  '31',
#  '36',
#  '52',
#  '33',
#  '45',
#  'thirty-six',
#  '60',
#  '50',
#  '44',
#  '47',
#  '42',
#  '43',
#  '40',
#  '29',
#  '53',
#  '23',
#  '55',
#  '26',
#  '34',
#  '27',
#  '35',
#  '30',
#  '34',
#  '52',
#  '33',
#  '35',
#  '28',
#  '36',
#  '34',
#  '34',
#  '44',
#  '32',
#  '53',
#  '22',
#  '44',
#  '35',
#  '25',
#  '49',
#  '24',
#  '38',
#  '29',
#  '43',
#  '28',
#  '20',
#  '47',
#  '22',
#  '28',
#  '39',
#  '33',
#  '36',
#  '35',
#  '31',
#  '33',
#  '27',
#  '30',
#  '24',
#  '35',
#  '30',
#  '48',
#  '41',
#  '27',
#  '35',
#  '26',
#  '33',
#  '26',
#  '38',
#  '46',
#  '20',
#  '30',
#  '27',
#  '55',
#  '33',
#  '28',
#  '34',
#  '33',
#  '33',
#  ...]

# %% [markdown]
# # CAMBIO EDAD

# %%
def transformar_age(lista): 
    lista_anios = []
    
    for age in lista: 
        
        try:
            age = int(age)
            lista_anios.append(age)  
        except: 
            numero_entero = w2n.word_to_num(age)  
            lista_anios.append(numero_entero)  
    
    return lista_anios

# %%
anios = transformar_age(lista_age)
print(anios)
len(anios)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 7, in transformar_age(lista)
#       6 try:
# ----> 7     age = int(age)
#       8     lista_anios.append(age)
#
# ValueError: invalid literal for int() with base 10: 'forty-seven'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 anios = transformar_age(lista_age)
#       2 print(anios)
#       3 len(anios)
#
# Cell In[6], line 10, in transformar_age(lista)
#       8         lista_anios.append(age)
#       9     except:
# ---> 10         numero_entero = w2n.word_to_num(age)
#      11         lista_anios.append(numero_entero)
#      13 return lista_anios
#
# NameError: name 'w2n' is not defined

# %%
lista_atr = df_data["Attrition"].to_list()
lista_atr
# Out:
# ['No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'Yes',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'Yes',
#  'Yes',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'Yes',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'Yes',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'Yes',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'Yes',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'Yes',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'Yes',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'Yes',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'Yes',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  ...]

# %%
def transformar_atr(lista): 
    lista_atrit = []
    
    for atr in lista: 
        
        try:
            if atr.lower() == 'yes' or 'no': 
                lista_atrit.append(atr)  
              
            else: 
                lista_atrit.append(None)   
        except: 
            print('Error de datos')
    
    return lista_atrit

# %%
atrit = transformar_atr(lista_atr)
atrit
len(atrit)
# Out:
# 1614

# %%
lista_travel = df_data["BusinessTravel"].to_list()
lista_travel
# Out:
# [nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_frequently',
#  'non-travel',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'non-travel',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  'non-travel',
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_frequently',
#  'travel_frequently',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  'non-travel',
#  'non-travel',
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_frequently',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'non-travel',
#  nan,
#  nan,
#  'travel_frequently',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_frequently',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_frequently',
#  nan,
#  'travel_frequently',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_frequently',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_frequently',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  'non-travel',
#  'travel_frequently',
#  'travel_frequently',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'non-travel',
#  'travel_rarely',
#  'travel_frequently',
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_frequently',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_frequently',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  'non-travel',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_frequently',
#  'travel_frequently',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'non-travel',
#  nan,
#  nan,
#  nan,
#  'non-travel',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'non-travel',
#  'travel_rarely',
#  nan,
#  'non-travel',
#  'non-travel',
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_frequently',
#  'non-travel',
#  'non-travel',
#  'non-travel',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_frequently',
#  'non-travel',
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_frequently',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_frequently',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'non-travel',
#  'travel_frequently',
#  'travel_frequently',
#  nan,
#  'travel_frequently',
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_frequently',
#  nan,
#  'travel_frequently',
#  'non-travel',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_frequently',
#  'travel_rarely',
#  'non-travel',
#  'travel_frequently',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  'non-travel',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  'non-travel',
#  nan,
#  'travel_rarely',
#  'non-travel',
#  nan,
#  'travel_frequently',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_frequently',
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_frequently',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  'non-travel',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_frequently',
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_frequently',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_frequently',
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'non-travel',
#  nan,
#  nan,
#  nan,
#  'travel_frequently',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_frequently',
#  nan,
#  nan,
#  'travel_rarely',
#  'non-travel',
#  'travel_rarely',
#  'non-travel',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_frequently',
#  'non-travel',
#  'non-travel',
#  'travel_frequently',
#  'travel_rarely',
#  nan,
#  'non-travel',
#  'travel_rarely',
#  nan,
#  'travel_frequently',
#  nan,
#  nan,
#  nan,
#  'travel_frequently',
#  'travel_frequently',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_frequently',
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'non-travel',
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  nan,
#  'non-travel',
#  'travel_frequently',
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'travel_frequently',
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'travel_frequently',
#  nan,
#  'non-travel',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'non-travel',
#  nan,
#  'travel_rarely',
#  'non-travel',
#  'travel_frequently',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_frequently',
#  'travel_frequently',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_frequently',
#  'travel_frequently',
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_frequently',
#  nan,
#  'travel_rarely',
#  'travel_frequently',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  'non-travel',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_frequently',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'non-travel',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_frequently',
#  'travel_rarely',
#  'travel_rarely',
#  'non-travel',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_frequently',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_frequently',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'non-travel',
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  'non-travel',
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_frequently',
#  nan,
#  'non-travel',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_frequently',
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_frequently',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_frequently',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_frequently',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_frequently',
#  nan,
#  'non-travel',
#  'travel_rarely',
#  nan,
#  'non-travel',
#  'travel_rarely',
#  nan,
#  nan,
#  'non-travel',
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_frequently',
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_frequently',
#  nan,
#  'travel_rarely',
#  nan,
#  'non-travel',
#  nan,
#  nan,
#  'non-travel',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_frequently',
#  nan,
#  nan,
#  nan,
#  'travel_frequently',
#  'travel_frequently',
#  'travel_rarely',
#  nan,
#  'non-travel',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_frequently',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_frequently',
#  'travel_rarely',
#  'non-travel',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_rarely',
#  'non-travel',
#  'non-travel',
#  'travel_frequently',
#  'travel_rarely',
#  'travel_frequently',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'non-travel',
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_frequently',
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  'non-travel',
#  'travel_rarely',
#  'travel_frequently',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'non-travel',
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_frequently',
#  nan,
#  'travel_frequently',
#  'travel_rarely',
#  'travel_frequently',
#  'travel_frequently',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_frequently',
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_frequently',
#  'travel_rarely',
#  'travel_frequently',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'non-travel',
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_frequently',
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'travel_frequently',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'non-travel',
#  nan,
#  nan,
#  'travel_frequently',
#  'travel_rarely',
#  nan,
#  'travel_frequently',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'non-travel',
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_frequently',
#  'travel_frequently',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  'non-travel',
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'non-travel',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_frequently',
#  'travel_frequently',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  'non-travel',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_frequently',
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_frequently',
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_frequently',
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'non-travel',
#  'travel_frequently',
#  nan,
#  'travel_frequently',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_frequently',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_frequently',
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_frequently',
#  nan,
#  'travel_rarely',
#  'non-travel',
#  'travel_rarely',
#  'travel_rarely',
#  'travel_frequently',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'travel_rarely',
#  nan,
#  'travel_rarely',
#  'non-travel',
#  'non-travel',
#  nan,
#  'travel_frequently',
#  nan,
#  nan,
#  nan,
#  'non-travel',
#  nan,
#  'travel_rarely',
#  nan,
#  nan,
#  nan,
#  nan,
#  ...]

# %%
def transformar_travel(lista): 
    lista_viajes= []
    contador = 0 
    
    for viaje in viajes: 
        
        try:
          
        except: 
            print('Error de datos')
    
    return lista_viajes
